# %%
#!/usr/bin/python
# -*- coding: UTF-8 -*-
import threading
import time
from queue import Queue
import requests
from bs4 import BeautifulSoup
#sql牛逼
import MySQLdb
#zz牛逼教我json
import json
#你看看你个菜鸡用多久
import datetime
#系统牛逼
import os
#历史记录？
import time
#正则表达式天下第一
import re

# %%
# 用来存放采集线程
g_crawl_list = []
# 用来存放解析线程
g_parse_list = []
ans_list=[]
tt=''

# %%
def start():
    #万事开头难
    global conn,curs
    conn = MySQLdb.connect("127.0.0.1", "root", "nideshengri", "nidekuzi", charset='utf8' )
    # 使用cursor()方法获取操作游标 
    curs = conn.cursor()

# %%
#插入游戏tag
def inserttag(idn,tags):
    for tag in tags.split(','):
        sql="""INSERT INTO `nidekuzi`.`id_tag`(SteamId,Tag) VALUES (%d,"%s")"""%(idn,tag.lstrip())
        #try:
        curs.execute(sql)
        #except:
            #conn.rollback()
        conn.commit()

# %%
#插入游戏的函数
def insertgame(mtag,idn,name,platforms,pic,price,tags):
    if len(price)==0:
        return      #价格为空意味着游戏已经下架
    name=filt_emo(name)     #为什么有人在游戏名里加emoji？
    name=transferContent(name)      #转义真是太难了太难了...
    price[0]=filt(price[0])
    price[-1]=filt(price[-1])
    if float(price[-1][:-1])==0:
        cut='0%'
    else:
        cut=str(int((float(price[-1][:-1])-float(price[0][:-1]))/float(price[-1][:-1])*100))
        cut=cut+'%'
    sql = """INSERT INTO `%s`(`SteamId`, `Name`,`Platforms`, `Pic_url`,`CurrentPrice`, `LowestPrice`, `OriginalPrice` , `Cut`)
             VALUES ('%d','%s','%s','%s','%s','%s','%s','%s')"""%(mtag,idn,name,platforms,pic,filt(price[0]),filt(price[0]),filt(price[-1]),cut)
    #try:
    curs.execute(sql)
    #except:
        #conn.rollback()
    conn.commit()
    inserttag(idn,tags)

# %%
#转义NMSL，代码我抄的https://blog.csdn.net/lengye7/article/details/79916685
def transferContent(content):
        if content is None:
            return None
        else:
            string = ""
            for c in content:
                if c == '"':
                    string += '\\\"'
                elif c == "'":
                    string += "\\\'"
                elif c == "\\":
                    string += "\\\\"
                else:
                    string += c
            return string

# %%
#求求你们不要在游戏名里加emoji了！！
def filt_emo(name):
    restr=''
    try:
        co = re.compile(u'[\U00010000-\U0010ffff]')
    except re.error:
        co = re.compile(u'[\uD800-\uDBFF][\uDC00-\uDFFF]')
    return co.sub(restr, name)

# %%
#金钱格式一定要统一啊....
def filt(price):
    price=re.findall("\d+\\.?\d*",price)
    if len(price)==0:
        return '0.00￥'
    else:
        price=float(price[0])
        return '%.2f￥'%price

# %%
#每日更新数据的函数
def updata(mtag,idn,name,platform,pic,price,tags):
    platforms=''
    for a in platform:
        platforms+=a
    sql="SELECT * FROM `%s` WHERE SteamId=%d"%(mtag,idn)
    curs.execute(sql)
    olddata=curs.fetchone()
    if olddata==None:#意味着有新游戏或者游戏遗漏，那么插入游戏
        insertgame(mtag,idn,name,platforms,pic,price,tags)
        return
    if price[0].isspace():
        price[0]=olddata[-4]
    price[0]=filt(price[0])
    if price[0] != olddata[-4]:
        recording(mtag,idn,price[0],time)
    if float(price[0][:-1]) <float(olddata[-1][:-1]):
        lowest=price[0]
    else:
        lowest=olddata[-1]
    if float(price[0][:-1])==0:
        cut='0%'
    else:
        cut=str(int((float(olddata[-3][:-1])-float(price[0][:-1]))/float(olddata[-3][:-1])*100))
        cut=cut+'%'

    sql='''UPDATE `%s` SET `Platforms` = '%s', `CurrentPrice` = '%s', `Cut` = '%s', `LowestPrice` = '%s' , `Pic_url` = '%s' WHERE `%s`.`SteamId` = %d'''%(mtag,platforms,price[0],cut,lowest,pic,mtag,idn)

    #try:
    curs.execute(sql)
    #except:
        #conn.rollback()
    conn.commit()

# %%
#在updata表里留下证据
def recording(mtag,idn,price,time):
    sql = """INSERT INTO `%sUpdata`(`SteamId`, `Price`)
             VALUES ('%d','%s')"""%(mtag,idn,price)
    #try:
    curs.execute(sql)
    #except:
        #conn.rollback()
    conn.commit()

# %%
#通用更新函数,没用到这个
#四个参数为表名，id，需要更新的数据，更新数据的字段名
def updatasql(mtag,idn,data,dataname):
    sql='''UPDATE `%s` SET `%s` = '%s' WHERE `%s`.`SteamId` = %d'''%(mtag,dataname,data,mtag,idn)
    #try:
    curs.execute(sql)
    #except:
        #conn.rollback()
    conn.commit()

# %%
class CrawlThread(threading.Thread):
    def __init__(self, name, page_queue, data_queue,block):
        super(CrawlThread, self).__init__()
        self.name = name
        self.page_queue = page_queue
        self.data_queue = data_queue
        self.block = block
        self.url = "https://store.steampowered.com/contenthub/querypaginated/tags/NewReleases/render/?query=&start={0}&count=15&cc=CN&l=english&v=4&tag={1}"
        self.headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/71.0.3578.98 Safari/537.36',
        }

    def run(self):
        print('%s----线程启动' % self.name)
        while 1:
            
            # 判断采集线程何时退出
            if self.page_queue.empty():
                break
            # 从队列中取出页码
            page = self.page_queue.get()
            # 拼接url，发送请求
            url = self.url.format(page,self.block)
            try:
                r = requests.get(url, headers=self.headers)
            except:
                self.page_queue.put(page)
                continue
            # 响应内容存放到data_queue中
            self.data_queue.put(r.text)
            print('{0}----采集{1}完毕'.format(self.name,page))
            time.sleep(3)
        print('%s----线程结束' % self.name)

class ParserThread(threading.Thread):
    def __init__(self, name, data_queue, lock):
        super(ParserThread, self).__init__()
        self.name = name
        self.data_queue = data_queue
        self.lock = lock

    def run(self):
        print('%s----线程启动' % self.name)
        while 1:
            try:
                #print('%s----线程正在干活' % self.name)
                # 从data_queue中取出一页数据
                data = self.data_queue.get(True, 10)
                # 解析内容
                self.parse_content(data)
            except Exception as e:
                print(e)
                break
        print('%s----线程结束' % self.name)

    def parse_content(self, info):
        try:
            info = json.loads(info)['results_html']
            game_block =  BeautifulSoup(info, 'html.parser')
        except:
            print("get info error")
            return
        global tt
        for games in game_block.contents[1::2]:
            pf=[]
            if games.find('span',class_="platform_img win"):
                pf.append("win")
            if games.find('span',class_="platform_img mac"):
                pf.append("mac")
            if games.find('span',class_="platform_img linux"):
                pf.append("linux")
            if games.find('img',class_="tab_item_cap_img")!=None:
                pic=[games.find('img',class_="tab_item_cap_img")['src']]
            game_name = games.find('div',class_="tab_item_name").string
            if games.find('div',class_="discount_final_price")!= None:
                game_price = [games.find('div',class_="discount_final_price").string]
            else:
                game_price = []
            game_tag = games.find_all('span',class_ = "top_tag")
            game_id = games['data-ds-appid']
            if games.find('div',class_="discount_original_price") !=None:
                game_price.append(games.find('div',class_="discount_original_price").string)
            tags = []
            for i in game_tag:
                tags.append(i.string)
            game_tag = "".join(tags)
            ans_list.append({'id':game_id,"name":game_name,"price":game_price,"tags":game_tag,'picture':pic,'platform':pf,'block':tt})
        self.lock.acquire()
        self.lock.release()

def get_page_number(block):
    req =  requests.get("https://store.steampowered.com/contenthub/querypaginated/tags/NewReleases/ConcurrentUsers/render/?query=&start=1&count=15&cc=CN&l=english&v=4&tag="+block)
    #print(json.loads(req.text).keys())
    try: 
        data = json.loads(req.text)['total_count']
    except:
        data = "0"
    return data

# 创建队列
def create_queue(block):
    # 创建页码队列
    page_queue = Queue()
    for page in [i for i in range(int(get_page_number(block))+15) if i%15==0]:
        page_queue.put(page)
    # 创建内容队列
    data_queue = Queue()
    return page_queue, data_queue

# 创建采集线程
def create_crawl_thread(page_queue, data_queue,block):
    crawl_name = ['采集线程1'+block, '采集线程2'+block, '采集线程3'+block,'采集线程4'+block,'采集线程5'+block,'采集线程6'+block]
    global g_crawl_list
    g_crawl_list=[]
    for name in crawl_name:
        # 创建一个采集线程
        tcrwal = CrawlThread(name, page_queue, data_queue,block)
        # 保存到列表中
        g_crawl_list.append(tcrwal)


# 创建解析线程
def create_parse_thread(data_queue, lock,block):
    parse_name = ['解析线程1'+block, '解析线程2'+block, '解析线程3'+block]
    global g_parse_list
    g_parse_list=[]
    for name in parse_name:
        # 创建一个解析线程
        tparse = ParserThread(name, data_queue, lock)
        # 保存到列表中
        g_parse_list.append(tparse)

# %%
def main():
    for block in ['Massively Multiplayer','Action','Adventure','Casual','Indie','RPG','Simulation','Racing','Sports','Strategy']:
        #
        global tt
        tt=block
        # 创建队列函数
        page_queue, data_queue = create_queue(block)
        # 打开文件
        # 创建锁
        lock = threading.Lock()
        # 创建采集线程
        create_crawl_thread(page_queue, data_queue,block)
        time.sleep(10)
        # 创建解析线程
        create_parse_thread(data_queue, lock,block)
        # 启动所有采集线程
        print(len(g_crawl_list))
        for tcrwal in g_crawl_list:
            tcrwal.start()
        # 启动所有解析线程
        for tparse in g_parse_list:
            tparse.start()
        # 主线程等待子线程结束
        print("等待前")
        for tcrwal in g_crawl_list:
            tcrwal.join()
        print("等待解析前")
        for tparse in g_parse_list:
            tparse.join()
        print("等待后")

        # 关闭文件
        print(block+"线程操作结束,爬取结束")
    print('主线程子线程全部结束')
    ks=datetime.datetime.now()
    start()
    for item in ans_list :
        try:
            updata(item['block'],int(item['id']),item['name'],item['platform'],item['picture'][0],item['price'],item['tags'])
        except:
            print(item['block'],item['id'],item['name'],item['platform'],item['picture'][0],item['price'],item['tags'])
    js=datetime.datetime.now()
    print(js-ks)
    # 关闭连接
    conn.close()

# %%
if __name__ == '__main__':
    main() 
    #每日更新数据
# Out:
# 线程6Indie----采集420完毕
# 采集线程1Indie----采集435完毕
# 采集线程3Indie----采集450完毕
# 采集线程4Indie----采集465完毕
# 采集线程2Indie----采集480完毕
# 采集线程5Indie----采集495完毕
# 采集线程1Indie----采集525完毕
# 采集线程3Indie----采集540完毕
# 采集线程4Indie----采集555完毕
# 采集线程2Indie----采集570完毕
# 采集线程5Indie----采集585完毕
# 采集线程1Indie----线程结束
# 采集线程3Indie----线程结束
# 采集线程4Indie----线程结束
# 采集线程2Indie----线程结束
# 采集线程5Indie----线程结束
#
# 解析线程1Indie----线程结束
#
# 解析线程2Indie----线程结束
#
# 解析线程3Indie----线程结束
# 采集线程6Indie----采集510完毕
# 采集线程6Indie----线程结束
# 等待解析前
# 等待后
# Indie线程操作结束,爬取结束
# 6
# 采集线程1RPG----线程启动
# 采集线程2RPG----线程启动
# 采集线程3RPG----线程启动
# 采集线程4RPG----线程启动
# 采集线程5RPG----线程启动
# 采集线程6RPG----线程启动
# 解析线程1RPG----线程启动
# 解析线程2RPG----线程启动
# 解析线程3RPG----线程启动等待前
#
# 采集线程1RPG----采集0完毕
# 采集线程2RPG----采集15完毕
# 采集线程4RPG----采集30完毕
# 采集线程3RPG----采集45完毕
# 采集线程6RPG----采集75完毕
# 采集线程5RPG----采集60完毕
# 采集线程1RPG----采集90完毕
# 采集线程2RPG----采集105完毕采集线程3RPG----采集135完毕采集线程4RPG----采集120完毕
#
#
# 采集线程6RPG----采集150完毕
# 采集线程5RPG----采集165完毕
# 采集线程3RPG----线程结束
# 采集线程2RPG----线程结束
# 采集线程4RPG----线程结束
# 采集线程6RPG----线程结束
# 采集线程5RPG----线程结束
# 采集线程1RPG----采集180完毕
# 采集线程1RPG----线程结束
# 等待解析前
#
# 解析线程1RPG----线程结束
#
# 解析线程2RPG----线程结束
#
# 解析线程3RPG----线程结束
# 等待后
# RPG线程操作结束,爬取结束
# 6
# 采集线程1Simulation----线程启动
# 采集线程2Simulation----线程启动
# 采集线程3Simulation----线程启动
# 采集线程4Simulation----线程启动
# 采集线程5Simulation----线程启动
# 采集线程6Simulation----线程启动
# 解析线程1Simulation----线程启动
# 解析线程2Simulation----线程启动
# 解析线程3Simulation----线程启动
# 等待前
# 采集线程3Simulation----采集15完毕
# 采集线程4Simulation----采集45完毕
# 采集线程5Simulation----采集60完毕采集线程1Simulation----采集30完毕采集线程2Simulation----采集0完毕
#
#
# 采集线程6Simulation----采集75完毕
# 采集线程3Simulation----采集90完毕
# 采集线程4Simulation----采集105完毕
# 采集线程6Simulation----采集165完毕
# 采集线程1Simulation----采集150完毕采集线程5Simulation----采集135完毕
#
# 采集线程2Simulation----采集120完毕
# 采集线程4Simulation----线程结束
# 采集线程3Simulation----采集180完毕
# 采集线程6Simulation----线程结束
# 采集线程5Simulation----线程结束采集线程1Simulation----线程结束
#
# 采集线程2Simulation----线程结束
# 采集线程3Simulation----线程结束
# 等待解析前
#
# 解析线程1Simulation----线程结束
#
# 解析线程2Simulation----线程结束
#
# 解析线程3Simulation----线程结束
# 等待后
# Simulation线程操作结束,爬取结束
# 6
# 采集线程1Racing----线程启动
# 采集线程2Racing----线程启动
# 采集线程3Racing----线程启动
# 采集线程4Racing----线程启动采集线程5Racing----线程启动
# 采集线程4Racing----线程结束
# 采集线程6Racing----线程启动
# 采集线程6Racing----线程结束
# 解析线程1Racing----线程启动
#
# 采集线程5Racing----线程结束
# 解析线程2Racing----线程启动
# 解析线程3Racing----线程启动等待前
#
# 采集线程3Racing----采集30完毕
# 采集线程1Racing----采集15完毕采集线程2Racing----采集0完毕
#
# 采集线程3Racing----线程结束
# 采集线程2Racing----线程结束
# 采集线程1Racing----线程结束
# 等待解析前
#
# 解析线程1Racing----线程结束
#
# 解析线程2Racing----线程结束
#
# 解析线程3Racing----线程结束
# 等待后
# Racing线程操作结束,爬取结束
# 6
# 采集线程1Sports----线程启动
# 采集线程2Sports----线程启动采集线程3Sports----线程启动
#
# 采集线程4Sports----线程启动
# 采集线程5Sports----线程启动采集线程6Sports----线程启动
#
# 采集线程6Sports----线程结束
# 解析线程1Sports----线程启动采集线程5Sports----线程结束
# 解析线程2Sports----线程启动
#
# 解析线程3Sports----线程启动
# 等待前
# 采集线程4Sports----采集45完毕
# 采集线程1Sports----采集0完毕采集线程3Sports----采集15完毕
#
# 采集线程2Sports----采集30完毕
# 采集线程4Sports----线程结束
# 采集线程1Sports----线程结束
# 采集线程3Sports----线程结束
# 采集线程2Sports----线程结束
# 等待解析前
#
# 解析线程2Sports----线程结束
#
# 解析线程3Sports----线程结束
#
# 解析线程1Sports----线程结束
# 等待后
# Sports线程操作结束,爬取结束
# 6
# 采集线程1Strategy----线程启动
# 采集线程2Strategy----线程启动
# 采集线程3Strategy----线程启动
# 采集线程4Strategy----线程启动
# 采集线程5Strategy----线程启动
# 采集线程6Strategy----线程启动
# 解析线程1Strategy----线程启动
# 解析线程2Strategy----线程启动
# 解析线程3Strategy----线程启动等待前
#
# 采集线程5Strategy----采集60完毕采集线程3Strategy----采集15完毕
#
# 采集线程1Strategy----采集30完毕
# 采集线程4Strategy----采集45完毕
# 采集线程2Strategy----采集0完毕
# 采集线程6Strategy----采集75完毕
# 采集线程3Strategy----采集90完毕
# 采集线程5Strategy----采集105完毕
# 采集线程4Strategy----采集135完毕
# 采集线程1Strategy----采集120完毕
# 采集线程6Strategy----采集165完毕
# 采集线程2Strategy----采集150完毕
# 采集线程5Strategy----线程结束
# 采集线程4Strategy----线程结束
# 采集线程1Strategy----线程结束
# 采集线程6Strategy----线程结束
# 采集线程3Strategy----采集180完毕
# 采集线程2Strategy----线程结束
# 采集线程3Strategy----线程结束
# 等待解析前
#
# 解析线程1Strategy----线程结束
#
# 解析线程3Strategy----线程结束
#
# 解析线程2Strategy----线程结束
# 等待后
# Strategy线程操作结束,爬取结束
# 主线程子线程全部结束
# Action 24010,980548,1055333,1098163 Train Simulator 2020 ['win'] https://media.st.dl.bscstorage.net/steam/subs/392644/capsule_184x69.jpg?t=1568911684 ['¥ 99'] Simulation, Trains, Singleplayer, Realistic
# Jenny LeClue - Detectivu
# TAISHO x ALICE episode 1
# Creme de la Creme
# 妄想破绽 Broken Delusion
# 境界 Dice&Fighter
# Shine\'s Adventures 6 (Go! Girls)
# Escape the Ayuwoki
# Death Park
# The Sphere of Abyss
# Nyanco Dream
# 天降锦鲤 ~ My Lucky Koi
# Nevrosa: Primal Ritual
# LOST EMBER
# Banter Schooldays!!三〇一室无一人
# XP Girls
# WarriOrb: Prologue
# Raccoo Venture
# MAN STANDING
# Shovel Knight: King of Cards
# BONEWORKS
# STEINS;GATE: My Darling\'s Embrace
# Hello Neighbor: Hide and Seek
# LAMUNATION! -international-
# Kings of Lorn: The Fall of Ebris
# Black Future \'88
# Bug Fables: The Everlasting Sapling
# Asterix & Obelix XXL 3  - The Crystal Menhir
# Reign of Darkness
# Still There
# Sweet Thomas
# Rocwood Academy
# The Leopard Catgirl in Miaoli
# Eternal Dread 2
# Vladimir Putin Style
# Death Gasp VR
# Forgotten Hill Disillusion
# HENTAI SNIPER: Middle East
# RUSSI.A SIMULATOR
# DRAGON QUEST BUILDERS™ 2
# Layers of Fear VR
# Frog Detective 2: The Case of the Invisible Wizard
# Earthshine
# West Sweety
# 3000th Duel
# Sayonara Wild Hearts
# A Gay\'s Life
# Inunaki Tunnel | 犬鳴トンネル
# Oil Mogul
# Budget Cuts 2: Mission Insolvency
# 巫师超凡者 Legend of the wizard
# Kelipot / 形骸骑士
# Ashen
# Uncharted Ocean
# Little Dungeon Stories
# Combat Force
# Suite 776
# Natsu no Iro no Nostalgia
# Seek Girl Ⅲ
# 游离大陆 Uniland
# Darksiders Genesis
# Boiling Steel
# Interrogation: You will be deceived
# Red Dead Redemption 2
# HENTAI REDEMPTION
# Edna & Harvey: The Breakout - Anniversary Edition
# Hentai : Shoot Them
# ToGather:Island
# Press Forward OOOOONNNNN
# Tools Up!
# Nancy Drew®: Midnight in Salem
# Valakas Story
# MANIC
# Fear the Dark Unknown
# Island Marauder
# Ope
# Nexomon
# Miracle Calamity Homeostasis
# Skelittle: A Giant Party!!
# Open World Game: the Open World Game
# Forbidden Love With The Ghost Girl
# Kyle is Famous
# ANNIE: Last Hope
# Pixel Puzzles Traditional Jigsaws
# Paul\'s World
# Skyland 1976
# 反现实症候群γ - Counterrealstic Syndrome γ
# RED EVIL
# Armortale
# Woven
# ALIA’s CARNIVAL！
# Holy Knight Luviria
# STAR WARS Jedi: Fallen Order™
# Blacksad: Under the Skin
# Terminator: Resistance
# Some Distant Memory
# Deadliest Catch: The Game
# The War for the West
# Breach: The Archangel Job
# Fractured Minds
# The Curious Tale of the Stolen Pets
# Putin Life
# FULFILLMENT
# The Legend of Bum-Bo
# Devil Slayer - Raksasi
# Last Labyrinth（ラストラビリンス）
# 奇迹一刻 Surmount
# Discolored
# There is No GreenDam
# HUNTERS FOR YOUR BRAIN
# Wurroom
# Somewhere inside
# ELYSION
# The Princess, the Stray Cat, and Matters of the Heart 2
# Apostle
# Skybolt Zack
# Abode 2
# The Coma 2: Vicious Sisters
# The Story of Henry Bishop
# 跳跃2/LeapII
# When The Past Was Around - Prologue
# Brukel
# Rift Racoon
# AVA: Dark History
# Spooky Station
# Polyroll
# Flyeeex
# Mystery Island - Hidden Object Games
# Escape Mind
# New Tricks for Old Gods
# The Last Companion-我与我行将离去的小友。
# MMY: Otherworld Mystery
# RRRR3
# War Solution - Casual Math Game
# Kamile: The Fall
# The Terrible Old Man
# Worse Than Death
# 初恋日记
# Karar X
# Last Days Of Tascaria
# Zelle
# The Land of Exile
# Weeping Willow - Detective Visual Novel
# Shine\'s Adventures 2 (Zombie Attack)
# Angelo and Deemon: One Hell of a Quest
# 无奇刀 Wookie\'s Blade
# Super Cucho
# HalloweenStory
# AVA
# MMX
# OSK - The End of Time
# Too White Basketball
# Sweet Thomas
# Magicolors
# Rocwood Academy
# Vladimir Putin Style
# Shadow Brawlers
# West Sweety
# Pretty Angel
# The Answer Is 42
# Touring Karts
# Sayonara Wild Hearts
# Hop Step Sing! Astral Piece
# ClickCells: Office Lady
# Winter Resort Simulator
# 巫师超凡者 Legend of the wizard
# Classic Sudoku
# 6.0
# 天降锦鲤 ~ My Lucky Koi
# RetroVamp
# Defence War
# LAMUNATION! -international-
# Colorgrid
# Reign of Darkness
# Unlock The King
# Hentai Crush: Love Rhythm
# Legion 51
# A Gay\'s Life
# Tools Up!
# Valakas Story
# Glyph
# Nexomon
# Miracle Calamity Homeostasis
# Biker Garage: Mechanic Simulator
# unitied
# Creme de la Creme
# Rock Simulator
# WIDE CROSS
# ALIA’s CARNIVAL！
# Ultimate Fishing Simulator VR
# Some Distant Memory
# Masteroid
# 境界 Dice&Fighter
# Toy Robot
# Shine\'s Adventures 6 (Go! Girls)
# Truck Life
# The Curious Tale of the Stolen Pets
# Eternal Essence
# Hold Your Ground
# Putin Life
# Mr. Pumpkin 2: Kowloon walled city
# FULFILLMENT
# Jigsaw Women 2
# NABOKI
# DRAW CHILLY
# Zup! F
# AVICII Invector
# Frog Detective 2: The Case of the Invisible Wizard
# Earthshine
# Uncharted Ocean
# Rag Doll Joe
# Little Dungeon Stories
# Natsu no Iro no Nostalgia
# Retimed
# Shape Cascade
# Press Forward OOOOONNNNN
# Inunaki Tunnel | 犬鳴トンネル
# Oil Mogul
# FIT Food
# Croixleur Sigma - Deluxe Edition
# Pixel Puzzles Traditional Jigsaws
# Paul\'s World
# Spring Falls
# XANARTHRAXIA
# Mad Machines
# Armortale
# Woven
# Beyond Shattered Isles
# Discolored
# Touhou Ibunseki - Ayaria Dawn: ReCreation
# Master Of Pottery
# Explosive Jake
# The TakeOver
# Space Candy
# Space Wars
# Wurroom
# The Princess, the Stray Cat, and Matters of the Heart 2
# PC Fútbol Stars
# Voxelgram
# Garfield Kart - Furious Racing
# Planet Zoo
# When The Past Was Around - Prologue
# One day
# AVA: Dark History
# Spooky Station
# Daylife in Japan - Pixel Art Jigsaw Puzzle
# Mystery Island - Hidden Object Games
# Escape Mind
# Mini Words - minimalist puzzle
# Richman10
# Rude Racers: 2D Combat Racing
# My Typing Skill
# MMY: Otherworld Mystery
# Best Plumber
# War Solution - Casual Math Game
# Morok
# Tower Hunter: Erza\'s Trial
# Weeping Willow - Detective Visual Novel
# HalloweenStory
# AVA
# MMX
# Casual 24010,980548,1055333,1098163 Train Simulator 2020 ['win'] https://media.st.dl.bscstorage.net/steam/subs/392644/capsule_184x69.jpg?t=1568911684 ['¥ 99'] Simulation, Trains, Singleplayer, Realistic
# Shine\'s Adventures 2 (Zombie Attack)
# 无奇刀 Wookie\'s Blade
# Karate Cat
# Tools Up!
# MANIC
# Glyph
# Fear the Dark Unknown
# Island Marauder
# SwarmZ
# Ope
# Neon Noodles - Cyberpunk Kitchen Automation
# Nexomon
# Miracle Calamity Homeostasis
# Biker Garage: Mechanic Simulator
# Skelittle: A Giant Party!!
# unitied
# Too White Basketball
# Magicolors
# 血战夹皮沟
# Shera and the Three Treasures
# Rocwood Academy
# The Leopard Catgirl in Miaoli
# TSM3:Gemini Strategy/双子战纪
# Barrage Musical ~ Basic Danmaku Tutorial ~ / 弹幕音乐绘 ~ 基础教学篇 ~
# Eternal Dread 2
# Onset
# Vladimir Putin Style
# Death Gasp VR
# West Sweety
# Pretty Angel
# 3000th Duel
# Interrogation: You will be deceived
# Shape Cascade
# Day of Dragons
# HENTAI REDEMPTION
# Door in the Woods
# Edna & Harvey: The Breakout - Anniversary Edition
# Paunch
# The Answer Is 42
# Hentai : Shoot Them
# ToGather:Island
# Sayonara Wild Hearts
# Virgo Versus The Zodiac
# ClickCells: Office Lady
# Budget Cuts 2: Mission Insolvency
# Jamestown+
# Winter Resort Simulator
# 巫师超凡者 Legend of the wizard
# Press Forward OOOOONNNNN
# Kelipot / 形骸骑士
# AFTERBURN
# Vampire: The Masquerade - Coteries of New York
# WarriOrb: Prologue
# Raccoo Venture
# Not For Broadcast: Prologue
# GENSOU Skydrift
# Zup! F
# MAN STANDING
# Shovel Knight: King of Cards
# BONEWORKS
# Hades
# Layers of Fear VR
# AVICII Invector
# Last Year
# Frog Detective 2: The Case of the Invisible Wizard
# Earthshine
# Uncharted Ocean
# Rag Doll Joe
# Little Dungeon Stories
# Combat Force
# Suite 776
# Seek Girl Ⅲ
# 游离大陆 Uniland
# Retimed
# Boiling Steel
# Classic Sudoku
# The Sphere of Abyss
# Nyanco Dream
# 天降锦鲤 ~ My Lucky Koi
# Nevrosa: Primal Ritual
# RetroVamp
# Overstep
# Defence War
# Brass Brigade
# LOST EMBER
# The Political Process
# Banter Schooldays!!三〇一室无一人
# XP Girls
# Creme de la Creme
# 妄想破绽 Broken Delusion
# Hentai Nazi
# Re-O-Ri
# Story of a Gladiator
# Rock Simulator
# Stay Out
# WIDE CROSS
# 境界 Dice&Fighter
# Toy Robot
# Shine\'s Adventures 6 (Go! Girls)
# Escape the Ayuwoki
# 觅长生
# Death Park
# Kings of Lorn: The Fall of Ebris
# Plutocracy
# Black Future \'88
# Bug Fables: The Everlasting Sapling
# Party Pumper
# Rituals in the Dark
# Automation Empire
# Reign of Darkness
# Still There
# Forgotten Hill Disillusion
# HENTAI SNIPER: Middle East
# Hentai Crush: Love Rhythm
# Legion 51
# This Land Is My Land
# A Gay\'s Life
# Adam: Robot World
# Inunaki Tunnel | 犬鳴トンネル
# Oil Mogul
# Open World Game: the Open World Game
# Forbidden Love With The Ghost Girl
# Croixleur Sigma - Deluxe Edition
# Kyle is Famous
# ANNIE: Last Hope
# Ultimate Fishing Simulator VR
# Holy Knight Luviria
# Some Distant Memory
# Deadliest Catch: The Game
# The War for the West
# Breach: The Archangel Job
# Of Ships & Scoundrels
# Fractured Minds
# The Curious Tale of the Stolen Pets
# Eternal Essence
# Soko Loco Deluxe
# Pixel Puzzles Traditional Jigsaws
# Paul\'s World
# Air Marty
# Spring Falls
# Skyland 1976
# 反现实症候群γ - Counterrealstic Syndrome γ
# XANARTHRAXIA
# RED EVIL
# Mad Machines
# Mr. Hopp\'s Playhouse
# Armortale
# Woven
# Wildermyth
# Putin Life
# Mr. Pumpkin 2: Kowloon walled city
# Chrono\'s Arena
# FULFILLMENT
# NABOKI
# Synthesis Universe -Episode 00-
# The Legend of Bum-Bo
# Unity of Command II
# DRAW CHILLY
# Thief Simulator VR
# Devil Slayer - Raksasi
# Last Labyrinth（ラストラビリンス）
# Beyond Shattered Isles
# 奇迹一刻 Surmount
# Discolored
# Touhou Ibunseki - Ayaria Dawn: ReCreation
# Master Of Pottery
# Down Ward
# Explosive Jake
# HUNTERS FOR YOUR BRAIN
# Space Candy
# Space Wars
# Wurroom
# Lurk in the Dark : Prologue
# Grunt1914
# 罪業狂襲FrenzyRetribution
# UBERMOSH:OMEGA
# Somewhere inside
# ELYSION
# 3 Blind Mice: A Remediation Game for Improper Children
# Apostle
# Pistol Whip
# Skybolt Zack
# The Coma 2: Vicious Sisters
# PC Fútbol Stars
# Voxelgram
# The Story of Henry Bishop
# SUPERVERSE
# 勇士HERO
# 跳跃2/LeapII
# When The Past Was Around - Prologue
# Return Of The Zombie King
# One day
# Reanimation Inc.
# Rift Racoon
# Spooky Station
# Polyroll
# Flyeeex
# Mystery Island - Hidden Object Games
# Escape Mind
# Mini Words - minimalist puzzle
# New Tricks for Old Gods
# Rude Racers: 2D Combat Racing
# My Typing Skill
# The Last Companion-我与我行将离去的小友。
# RRRR3
# Best Plumber
# War Solution - Casual Math Game
# Kamile: The Fall
# Chernobylite
# Morok
# MageQuit
# Blocks!: Richard III
# Necrolepsy
# Karate Cat
# The Terrible Old Man
# Worse Than Death
# 初恋日记
# Karar X
# Last Days Of Tascaria
# Zelle
# The Land of Exile
# Arkan: The dog adventurer
# Particle Wars
# Shine\'s Adventures 2 (Zombie Attack)
# Angelo and Deemon: One Hell of a Quest
# 无奇刀 Wookie\'s Blade
# Super Cucho
# AVA
# MMX
# OSK - The End of Time
# 血战夹皮沟
# Shera and the Three Treasures
# TSM3:Gemini Strategy/双子战纪
# Eternal Dread 2
# Onset
# Vladimir Putin Style
# West Sweety
# Pretty Angel
# Virgo Versus The Zodiac
# 巫师超凡者 Legend of the wizard
# Vampire: The Masquerade - Coteries of New York
# WarriOrb: Prologue
# Hades
# XANARTHRAXIA
# Holy Knight Luviria
# Terminator: Resistance
# The War for the West
# Breach: The Archangel Job
# Wildermyth
# Putin Life
# Chrono\'s Arena
# DRAW CHILLY
# Romancing SaGa 3
# 罪業狂襲FrenzyRetribution
# Somewhere inside
# Bug Fables: The Everlasting Sapling
# Reign of Darkness
# HENTAI SNIPER: Middle East
# Hentai Crush: Love Rhythm
# Legion 51
# This Land Is My Land
# A Gay\'s Life
# Open World Game: the Open World Game
# BatMUD
# 盛世传奇
# ANNIE: Last Hope
# DRAGON QUEST BUILDERS™ 2
# Omega Labyrinth Life
# Paul\'s World
# Ashen
# Uncharted Ocean
# Little Dungeon Stories
# I will eat you
# Seek Girl Ⅲ
# Darksiders Genesis
# Interrogation: You will be deceived
# HENTAI REDEMPTION
# Door in the Woods
# Paunch
# Hentai : Shoot Them
# Nexomon
# Creme de la Creme
# Stay Out
# Shine\'s Adventures 6 (Go! Girls)
# 觅长生
# The Sphere of Abyss
# Nyanco Dream
# 天降锦鲤 ~ My Lucky Koi
# Nevrosa: Primal Ritual
# XP Girls
# Apostle
# One day
# Spooky Station
# 初恋日记
# Last Days Of Tascaria
# Zelle
# The Land of Exile
# Shine\'s Adventures 2 (Zombie Attack)
# 无奇刀 Wookie\'s Blade
# Too White Basketball
# Rocwood Academy
# Onset
# Vladimir Putin Style
# Lumberjack Simulator
# West Sweety
# Pretty Angel
# Reiner Knizia Yellow & Yangtze
# Winter Resort Simulator
# 巫师超凡者 Legend of the wizard
# AFTERBURN
# Not For Broadcast: Prologue
# MAN STANDING
# Transport Fever 2
# Hurtworld
# BONEWORKS
# Uncharted Ocean
# Combat Force
# Interrogation: You will be deceived
# Day of Dragons
# HENTAI REDEMPTION
# ToGather:Island
# Tools Up!
# SwarmZ
# Neon Noodles - Cyberpunk Kitchen Automation
# Nexomon
# Biker Garage: Mechanic Simulator
# Rock Simulator
# Shine\'s Adventures 6 (Go! Girls)
# Truck Life
# The Political Process
# LAMUNATION! -international-
# Plutocracy
# The Magician\'s Research
# Rituals in the Dark
# Automation Empire
# HENTAI SNIPER: Middle East
# RUSSI.A SIMULATOR
# Hentai Crush: Love Rhythm
# Legion 51
# This Land Is My Land
# Adam: Robot World
# Inunaki Tunnel | 犬鳴トンネル
# Oil Mogul
# Open World Game: the Open World Game
# Football Manager 2020
# Football Manager 2020 Touch
# Pixel Puzzles Traditional Jigsaws
# Gear City Against Chaos
# Warhammer: Chaos And Conquest
# IL DIVINO: Michelangelo\'s Sistine Ceiling in VR
# 奇迹一刻 Surmount
# Touhou Ibunseki - Ayaria Dawn: ReCreation
# Master Of Pottery
# Deadliest Catch: The Game
# Space Candy
# Space Wars
# Grunt1914
# MM Garden
# Masteroid
# Command: Modern Operations
# 3 Blind Mice: A Remediation Game for Improper Children
# Soko Loco Deluxe
# Putin Life
# Unity of Command II
# Thief Simulator VR
# Brukel
# Reanimation Inc.
# Best Plumber
# Chernobylite
# Simulation 24010,980548,1055333,1098163 Train Simulator 2020 ['win'] https://media.st.dl.bscstorage.net/steam/subs/392644/capsule_184x69.jpg?t=1568911684 ['¥ 99'] Simulation, Trains, Singleplayer, Realistic
# Blocks!: Richard III
# 初恋日记
# The Wild Eight
# WWE 2K20
# OMON Simulator
# The Long Drive
# Lumberjack Simulator
# GENSOU Skydrift
# Shine\'s Adventures 6 (Go! Girls)
# Tracks - The Family Friendly Open World Train Set Game
# Beyond Shattered Isles
# 肥啾大冒险
# 跳跃2/LeapII
# Rude Racers: 2D Combat Racing
# MageQuit
# 无奇刀 Wookie\'s Blade
# Oasis
# Too White Basketball
# Combat Force
# Paunch
# Press Forward OOOOONNNNN
# Shine\'s Adventures 6 (Go! Girls)
# Overstep
# Football Manager 2020 Touch
# Football Manager 2020
# Pixel Puzzles Traditional Jigsaws
# PC Fútbol Stars
# Rude Racers: 2D Combat Racing
# WWE 2K20
# 血战夹皮沟
# Rocwood Academy
# TSM3:Gemini Strategy/双子战纪
# Vladimir Putin Style
# 巫师超凡者 Legend of the wizard
# Transport Fever 2
# Uncharted Ocean
# Little Dungeon Stories
# Combat Force
# Seek Girl Ⅲ
# 游离大陆 Uniland
# Interrogation: You will be deceived
# Soko Loco Deluxe
# Wildermyth
# Putin Life
# The Legend of Bum-Bo
# Unity of Command II
# 奇迹一刻 Surmount
# Touhou Ibunseki - Ayaria Dawn: ReCreation
# Grunt1914
# Voxelgram
# Colorgrid
# Plutocracy
# Farmer\'s Dynasty
# Automation Empire
# Reign of Darkness
# Unlock The King
# HENTAI SNIPER: Middle East
# Legion 51
# A Gay\'s Life
# Strategic Command: World War I
# Press Forward OOOOONNNNN
# Battle Realms (+ Winter of the Wolf)
# SwarmZ
# Adam: Robot World
# Inunaki Tunnel | 犬鳴トンネル
# Oil Mogul
# unitied
# Re-O-Ri
# Ruthless Conquest
# WIDE CROSS
# 境界 Dice&Fighter
# Shine\'s Adventures 6 (Go! Girls)
# 觅长生
# Classic Sudoku
# Defence War
# Football Manager 2020
# Warhammer: Chaos And Conquest
# Pixel Puzzles Traditional Jigsaws
# Paul\'s World
# Gear City Against Chaos
# Mr. Hopp\'s Playhouse
# Age of Empires II: Definitive Edition
# Command: Modern Operations
# Of Ships & Scoundrels
# Eternal Essence
# Richman10
# MageQuit
# Last Days Of Tascaria
# Shine\'s Adventures 2 (Zombie Attack)
# Particle Wars
# Lost
# Action 24010,980548,1055333,1098163 Train Simulator 2020 ['win'] https://media.st.dl.bscstorage.net/steam/subs/392644/capsule_184x69.jpg?t=1568911684 ['¥ 99'] Simulation, Trains, Singleplayer, Realistic
# Cage of the Succubi
# Cage of the Succubi
# Oasis
# Simulation 24010,980548,1055333,1098163 Train Simulator 2020 ['win'] https://media.st.dl.bscstorage.net/steam/subs/392644/capsule_184x69.jpg?t=1568911684 ['¥ 99'] Simulation, Trains, Singleplayer, Realistic
# Oasis
# Action 24010,980548,1055333,1098163 Train Simulator 2020 ['win'] https://media.st.dl.bscstorage.net/steam/subs/392644/capsule_184x69.jpg?t=1568911684 ['¥ 99'] Simulation, Trains, Singleplayer, Realistic
# Oasis
# Oasis
# Casual 24010,980548,1055333,1098163 Train Simulator 2020 ['win'] https://media.st.dl.bscstorage.net/steam/subs/392644/capsule_184x69.jpg?t=1568911684 ['¥ 99'] Simulation, Trains, Singleplayer, Realistic
# Oasis
# Simulation 24010,980548,1055333,1098163 Train Simulator 2020 ['win'] https://media.st.dl.bscstorage.net/steam/subs/392644/capsule_184x69.jpg?t=1568911684 ['¥ 99'] Simulation, Trains, Singleplayer, Realistic
# The Political Process
# Action 24010,980548,1055333,1098163 Train Simulator 2020 ['win'] https://media.st.dl.bscstorage.net/steam/subs/392644/capsule_184x69.jpg?t=1568911684 ['¥ 99'] Simulation, Trains, Singleplayer, Realistic
# Casual 24010,980548,1055333,1098163 Train Simulator 2020 ['win'] https://media.st.dl.bscstorage.net/steam/subs/392644/capsule_184x69.jpg?t=1568911684 ['¥ 99'] Simulation, Trains, Singleplayer, Realistic
# Simulation 24010,980548,1055333,1098163 Train Simulator 2020 ['win'] https://media.st.dl.bscstorage.net/steam/subs/392644/capsule_184x69.jpg?t=1568911684 ['¥ 99'] Simulation, Trains, Singleplayer, Realistic
# Action 24010,980548,1055333,1098163 Train Simulator 2020 ['win'] https://media.st.dl.bscstorage.net/steam/subs/392644/capsule_184x69.jpg?t=1568911684 ['¥ 99'] Simulation, Trains, Singleplayer, Realistic
# The Emerald Tablet
# The Emerald Tablet
# The Emerald Tablet
# Simulation 24010,980548,1055333,1098163 Train Simulator 2020 ['win'] https://media.st.dl.bscstorage.net/steam/subs/392644/capsule_184x69.jpg?t=1568911684 ['¥ 99'] Simulation, Trains, Singleplayer, Realistic
# 0:00:08.097614
